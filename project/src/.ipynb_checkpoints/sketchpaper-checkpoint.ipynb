# %%
import numpy as np
import os
from os.path import join, basename
from scipy.io import wavfile
from IPython.display import Audio

import matplotlib.pyplot as plt

import scipy.signal as sps

# %%
esc_dir = '/mnt/data/ESC-50-master/audio/'

# %%
test_audio_path = '/mnt/data/ESC-50-master/audio/1-100032-A-0.wav'

# %%
fs, test_audio = wavfile.read(test_audio_path)

# %%
test_audio = test_audio.astype(float)

# %%
plt.plot(test_audio)
plt.show()

# %%
Audio(data=test_audio, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
_,_,stft = sps.stft(test_audio, fs=fs, nperseg=2048, noverlap=512, return_onesided=True, boundary='zeros', padded=True)

# %%
print(stft.shape)
# Out:
# (1025, 145)

# %%
stft[2,42]
# Out:
# (-2425.4106-558.96576j)

# %%
from librosa.feature import melspectrogram

# %%
ms = melspectrogram(y=test_audio, sr=fs, n_fft=2048, center=False, power=1.0)

# %%
ms.shape
# Out:
# (128, 427)

# %%
5*fs / 512
# Out:
# 430.6640625

# %%
220/1000 * fs
# Out:
# 9702.0

# %%
9702 / 512
# Out:
# 18.94921875

# %%
431 / 16
# Out:
# 26.9375

# %%
26 * 400
# Out:
# 10400

# %%
import glob
audio_list = glob.glob('/mnt/data/DCASE2019/Task1/TAU-urban-acoustic-scenes-2019-development/audio/*wav')

# %%
labels = ['airport', 'shopping_mall', 'metro_station', 'street_pedestrian', 'public_square', 'street_traffic', 'tram', 'bus', 'metro', 'park']

# %%
cities = ['amsterdam', 'barcelona', 'helsinki', 'lisbon', 'london', 'lyon', 'madrid', 'milan', 'prague', 'paris', 'stockholm', 'vienna']

# %%
tau_dict = {}

# %%
for label in labels:
    tau_dict[label] = {}
    for city in cities:
        tau_dict[label][city] = []
    for audio in audio_list:
        if label == 'metro':
            if label in audio and 'station' not in audio:
                for city in cities:
                    if city in audio:
                        tau_dict[label][city].append(basename(audio))
        else:
            if label in audio:
                for city in cities:
                    if city in audio:
                        tau_dict[label][city].append(basename(audio))

# %%
for label in tau_dict:
    print(label)
    s = 0
    for city in tau_dict[label]:
        #print(city, len(tau_dict[label][city]))
        s += len(tau_dict[label][city])
    print(s)
# Out:
# airport
# 1440
# shopping_mall
# 1440
# metro_station
# 1440
# street_pedestrian
# 1440
# public_square
# 1440
# street_traffic
# 1440
# tram
# 1440
# bus
# 1440
# metro
# 1440
# park
# 1440

# %%
airports = []
for audio in audio_list:
    if 'airport' in audio:
        airports.append(basename(audio))

# %%
print(airports)
# Out:
# ['airport-paris-206-6255-a.wav', 'airport-vienna-13-535-a.wav', 'airport-helsinki-3-120-a.wav', 'airport-barcelona-1-47-a.wav', 'airport-lyon-1095-43724-a.wav', 'airport-milan-1172-45261-a.wav', 'airport-helsinki-4-211-a.wav', 'airport-paris-206-6267-a.wav', 'airport-london-205-6222-a.wav', 'airport-lyon-1041-43045-a.wav', 'airport-lisbon-1000-43430-a.wav', 'airport-london-6-285-a.wav', 'airport-vienna-209-6386-a.wav', 'airport-lisbon-1114-43793-a.wav', 'airport-helsinki-4-177-a.wav', 'airport-london-6-287-a.wav', 'airport-helsinki-3-119-a.wav', 'airport-london-6-289-a.wav', 'airport-milan-1061-40892-a.wav', 'airport-lisbon-1000-40000-a.wav', 'airport-helsinki-204-6176-a.wav', 'airport-stockholm-12-495-a.wav', 'airport-prague-1034-40269-a.wav', 'airport-stockholm-11-459-a.wav', 'airport-barcelona-2-100-a.wav', 'airport-vienna-209-6357-a.wav', 'airport-helsinki-204-6159-a.wav', 'airport-paris-8-353-a.wav', 'airport-paris-8